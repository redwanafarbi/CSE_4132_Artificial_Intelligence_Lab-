# %% [markdown]
# ## Problem Statement:
# ### Implement a simple deep neural network (DNN) for solving the polynomial equation $𝑦 = 5𝑥^3 - 10𝑥^2 - 20𝑥 + 10$ with the following specifications:

# %% [markdown]
# ### Necessary Import

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
import random

# %% [markdown]
# ### a) Use three hidden-layers of sizes 32, 64, and 128 and display the generated DNN with the required number of parameters.

# %%
input = keras.Input(shape=(1,))
hidden_layer_1 = keras.layers.Dense(32, activation="relu")(input)
hidden_layer_2 = keras.layers.Dense(64, activation="relu")(hidden_layer_1)
hidden_layer_3 = keras.layers.Dense(128, activation="relu")(hidden_layer_2)
output = keras.layers.Dense(1, name = "output_layer")(hidden_layer_3)

model = keras.Model(input, output)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 1)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,625 (41.50 KB)
#  Trainable params: 10,625 (41.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### b) Generate training samples within the range of -20 to +20. Use an appropriate method for normalizing the training data in the range of -1 to +1

# %%
# Given Function
def function_y(x):
    return (5 * pow(𝑥,3)- 10 * pow(𝑥,2) - 20 * 𝑥 + 10)

# %%
# Data Generation
def generate_data(n):
    x = np.linspace(-20,20,n)
    y = function_y(x)
    return x,y

# %%
# Normalization
def normalize(x):
    min = np.min(x)
    max = np.max(x)
    return 2 * (x-min)/(max-min) - 1

# %%
# Generate Sample Data
x,y = generate_data(10_000)

len(x), len(y)
# Out:
# (10000, 10000)

# %%
# Normalize Dataset
x = normalize(x)
y = normalize(y)

# %% [markdown]
# ### c) Use 5% of the samples as test data and 5% of the samples as validation data and the rest of the data for training the DNN with an appropriate number of epochs.

# %%
# Combine features and labels
# x = [a for a in x]
data = list(zip(x, y))

# Shuffle data
random.seed(42)
random.shuffle(data)

# Split data
total_size = len(data)
test_split_idx = int(total_size * 0.05)
val_split_idx = test_split_idx * 2

test_data = data[:test_split_idx]
val_data = data[test_split_idx:val_split_idx]
train_data = data[val_split_idx:]

X_train, y_train = zip(*train_data)
X_val, y_val = zip(*val_data)
X_test, y_test = zip(*test_data)

X_train = np.array(X_train)
X_test = np.array(X_test)
X_val = np.array(X_val)
y_train = np.array(y_train)
y_test = np.array(y_test)
y_val = np.array(y_val)


print(f"Train: {len(X_train)}, {len(y_train)}")
print(f"Test: {len(X_test)}, {len(y_test)}")
print(f"Validation: {len(X_val)}, {len(y_val)}")
# Out:
# Train: 9000, 9000
# Test: 500, 500
# Validation: 500, 500

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss=keras.losses.mean_squared_error,
    metrics=[keras.metrics.R2Score()])

history = model.fit(X_train, y_train, epochs=20, validation_data=(X_val, y_val))
# Out:
# Epoch 1/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0325 - r2_score: 0.7727 - val_loss: 3.7735e-04 - val_r2_score: 0.9974
# Epoch 2/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.9793e-04 - r2_score: 0.9986 - val_loss: 4.3638e-05 - val_r2_score: 0.9997
# Epoch 3/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.7991e-05 - r2_score: 0.9997 - val_loss: 2.6907e-05 - val_r2_score: 0.9998
# Epoch 4/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.2214e-05 - r2_score: 0.9999 - val_loss: 8.9115e-06 - val_r2_score: 0.9999
# Epoch 5/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 6.2901e-06 - r2_score: 1.0000 - val_loss: 3.4786e-06 - val_r2_score: 1.0000
# Epoch 6/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.0836e-06 - r2_score: 0.9999 - val_loss: 1.9836e-06 - val_r2_score: 1.0000
# Epoch 7/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 4.9576e-06 - r2_score: 1.0000 - val_loss: 1.2806e-05 - val_r2_score: 0.9999
# Epoch 8/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 1.0468e-05 - r2_score: 0.9999 - val_loss: 1.0814e-05 - val_r2_score: 0.9999
# Epoch 9/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 1.0598e-05 - r2_score: 0.9999 - val_loss: 1.4062e-06 - val_r2_score: 1.0000
# Epoch 10/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0627e-05 - r2_score: 0.9999 - val_loss: 3.2421e-05 - val_r2_score: 0.9998
# Epoch 11/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.4406e-05 - r2_score: 0.9998 - val_loss: 1.4356e-06 - val_r2_score: 1.0000
# Epoch 12/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.7678e-05 - r2_score: 0.9999 - val_loss: 3.5584e-06 - val_r2_score: 1.0000
# Epoch 13/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.0033e-05 - r2_score: 0.9999 - val_loss: 1.1873e-04 - val_r2_score: 0.9992
# Epoch 14/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3300e-05 - r2_score: 0.9997 - val_loss: 1.1603e-04 - val_r2_score: 0.9992
# Epoch 15/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.7296e-05 - r2_score: 0.9997 - val_loss: 4.5394e-06 - val_r2_score: 1.0000
# Epoch 16/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.4905e-06 - r2_score: 1.0000 - val_loss: 1.2252e-06 - val_r2_score: 1.0000
# Epoch 17/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2651e-06 - r2_score: 1.0000 - val_loss: 3.0378e-06 - val_r2_score: 1.0000
# Epoch 18/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.9951e-05 - r2_score: 0.9999 - val_loss: 1.5569e-06 - val_r2_score: 1.0000
# Epoch 19/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.8770e-06 - r2_score: 1.0000 - val_loss: 2.1114e-05 - val_r2_score: 0.9999
# Epoch 20/20
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.7854e-05 - r2_score: 0.9998 - val_loss: 1.8579e-06 - val_r2_score: 1.0000

# %% [markdown]
# ### d) Display the training accuracy vs validation accuracy and training error vs validation error curves.

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], '.-')
plt.plot(history.history['val_loss'], '.-')

plt.xlabel('Epoch')
plt.ylabel('Categorical Crossentropy Loss')
plt.legend(["Train", "Validation"])
plt.title('Loss VS Epoch')
plt.grid('on')


plt.subplot(1, 2, 2)
plt.plot(history.history['r2_score'], '.-')
plt.plot(history.history['val_r2_score'], '.-')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(["Train", "Validation"])
plt.title('Accuracy VS Epoch')
plt.grid('on')

# %%
# Evaluate the Model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9670e-06 - r2_score: 1.0000
# Test Loss: 2.091976966767106e-06
# Test Accuracy: 0.999984860420227

# %%
predictions = model.predict(X_test)

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.scatter(X_test,y_test)

plt.xlabel('X_test')
plt.ylabel('y_test')
plt.legend(["True Levels"])
plt.title('Truth')
plt.grid('on')


plt.subplot(1, 2, 2)
plt.scatter(X_test,y_test)
plt.scatter(X_test,predictions)

plt.xlabel('X_test')
plt.ylabel('y_test')
plt.legend(["True Levels", "Predicted Levels"])
plt.title('Truth vs Prediction')
plt.grid('on')
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
